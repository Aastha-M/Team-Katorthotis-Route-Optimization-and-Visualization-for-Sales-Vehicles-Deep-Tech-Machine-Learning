# %%
# %tensorflow_version 1.x
import numpy as np
import random
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

from collections import deque

import pickle
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
class env_opt_sd1:
  def one_encode(self,n1,n2,l,i1,i2,mem):
    cs=np.zeros(l*3)
    cs[n1]=i1
    for i in n2:
      cs[i+l]=i2
    cs[2*l:]=mem
    return(cs)
  def __init__(self,s,d):
    self.jun_link=[[1,3],[0,2],[1,3,4],[0,2,5],[2,5],[3,4]]
    self.jun_dist=[[10,15],[10,5],[5,7,3],[15,7,11],[3,7],[7,11]]
    self.memory=np.zeros(len(self.jun_link))
    self.memory[s]=1
    self.pos=s
    self.targs=d
    self.state=self.one_encode(s,d,len(self.jun_link),len(self.jun_link[s]),1,self.memory)
    self.game_fold=r'/content/drive/My Drive/Colab Notebooks/sales_vehicle/optimization/j2js_opt/game1/episodes'
    self.episode=1
    self.actions=np.array(['1','2','3'])
    #self.action_dict={0:'n',1:'ne',2:'e',3:'se',4:'s',5:'sw',6:'w',7:'nw'}
    #self.r_dict={'n':-1,'ne':-1,'e':0,'se':1,'s':1,'sw':1,'w':0,'nw':-1}
    #self.c_dict = {'n': 0, 'ne': 1, 'e': 1, 'se': 1, 's': 0, 'sw': -1, 'w': -1, 'nw': -1}
    #self.rw_max=self.rmax*self.cmax
    self.net_rw=0
    self.n_steps=1
    self.txt_init()
  def list_data(self):
    fn=self.game_fold+'/'+'jun_link.data'
    with open(fn, 'wb') as filehandle:
      pickle.dump(self.jun_link, filehandle)
    fn=self.game_fold+'/'+'jun_dist.data'
    with open(fn, 'wb') as filehandle:
      pickle.dump(self.jun_dist, filehandle)
  def txt_init(self):
        fp=self.game_fold+'/'+str(self.episode)+'.txt'
        f=open(fp,'w')
        s=str(self.pos)#+','#+str(self.targ)+'\n'
        for i in self.targs:
          s+=','+str(i)
        s+='\n'
        f.write(s)
        f.close()
  def txt_log(self):
        s=str(self.pos)+'\n'
        fp=self.game_fold+'/'+str(self.episode)+'.txt'
        f=open(fp,'a')
        f.write(s)
        f.close()
  def action_sample(self):
    return(random.randint(0,len(self.jun_link[self.pos])-1))
  def state_update(self):
    ls=len(self.state)
    state=np.zeros(ls)
    l=int(ls/3)
    cs=np.zeros(l)
    cs[self.pos]=len(self.jun_link[self.pos])
    t=np.zeros(l)
    for i in self.targs:
      t[i]=1
    mem=self.memory
    state[0:l]=cs
    state[l:2*l]=t
    state[2*l:]=mem
    self.state=state

  def step(self,action):
    #check position if valid
    self.n_steps+=1
    temp=len(self.jun_link[self.pos])
    if(action>=temp):
      reward=-100  ## May need to alter
      done=0
      print("invalid move")
      #print("ation:"+str(action))
      #print("temp"+str(temp))
    else:
      new_pos=self.jun_link[self.pos][action]
      #check if target is reached
      if(new_pos in self.targs):
        reward=10  ## may need to alter
        self.targs.remove(new_pos)
        self.memory=np.zeros(len(self.jun_link))
        self.pos=new_pos
        self.memory[self.pos]=1
        self.state_update()
        if(len(self.targs)==0):
          done=2
          reward=100
          print('All targets reached')
        else:
          done=0
          reward=10
          print('one of the target reached')
      else:
        ##check target memory
        #print(self.memory[new_pos])
        #print(self.memory)
        #print(new_pos)
        if(self.memory[new_pos]==1):
          reward=-10 ## May need to alter
          done=1
          print("Repeated destination")
        else:
          self.memory[new_pos]=1
          self.pos=new_pos
          self.state_update()
          reward=-1  #may need to reinforce exploration
          done=0
          print("moved to valid position")
    self.txt_log()
    self.net_rw+=reward
    return(self.state,reward,done)
  def reset(self,s,d):
    self.memory=np.zeros(len(self.jun_link))
    self.memory[s]=1
    self.pos=s
    self.targ=d
    self.state=self.one_encode(s,d,len(self.jun_link),len(self.jun_link[s]),1,self.memory)
    self.episode+=1
    
    #self.action_dict={0:'n',1:'ne',2:'e',3:'se',4:'s',5:'sw',6:'w',7:'nw'}
    #self.r_dict={'n':-1,'ne':-1,'e':0,'se':1,'s':1,'sw':1,'w':0,'nw':-1}
    #self.c_dict = {'n': 0, 'ne': 1, 'e': 1, 'se': 1, 's': 0, 'sw': -1, 'w': -1, 'nw': -1}
    #self.rw_max=self.rmax*self.cmax
    self.net_rw=0
    self.n_steps=1
    self.txt_init()

# %%
class DQN:
    def __init__(self, env):
        self.env = env
        self.memory = deque(maxlen=200000)

        self.gamma = 0.85
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.01
        self.tau = .125

        self.model = self.create_model()
        self.target_model = self.create_model()
        #self.model.summary()
        #self.target_model.summary()

    def create_model(self):
        model = Sequential()
        state_shape = self.env.state.shape      #self.env.observation_space.shape
        print('action_shape:')
        print(self.env.actions.shape[0])
        model.add(Dense(64, input_dim=state_shape[0], activation="relu"))
        model.add(Dense(64, activation="relu"))
        model.add(Dense(32, activation="relu"))
        model.add(Dense(32, activation="relu"))
        model.add(Dense(16, activation="relu"))
        model.add(Dense(self.env.actions.shape[0]))
        model.compile(loss="mean_squared_error",
                      optimizer=Adam(lr=self.learning_rate))
        return model

    def act(self, state):
        self.epsilon *= self.epsilon_decay
        self.epsilon = max(self.epsilon_min, self.epsilon)
        if np.random.random() < self.epsilon:
            return self.env.action_sample()
        return np.argmax(self.model.predict(state)[0])

    def remember(self, state, action, reward, new_state, done):
        self.memory.append([state, action, reward, new_state, done])

    def replay(self):
        batch_size = 32
        if len(self.memory) < batch_size:
            return

        samples = random.sample(self.memory, batch_size)
        for sample in samples:
            state, action, reward, new_state, done = sample
            target = self.target_model.predict(state)
            # print(type(target))
            # print(target.shape)
            if done:
                target[0][action] = reward
            else:
                Q_future = max(self.target_model.predict(new_state)[0])
                target[0][action] = reward + Q_future * self.gamma
            self.model.fit(state, target, epochs=1, verbose=0)

    def target_train(self):
        weights = self.model.get_weights()
        target_weights = self.target_model.get_weights()
        for i in range(len(target_weights)):
            target_weights[i] = weights[i] * self.tau + target_weights[i] * (1 - self.tau)
        self.target_model.set_weights(target_weights)

    def save_model(self, fn):
        self.model.save('/content/drive/My Drive/Colab Notebooks/sales_vehicle/optimization/j2js_opt/game1/models/'+fn)

# %%
def randsd(env):
  s=random.randint(0,len(env.jun_link)-1)
  d=random.randint(2,len(env.jun_link))
  targ=[]
  for i in range(d):
    temp=random.randint(0,len(env.jun_link)-1)
    if(temp==s or temp in targ):
      continue
    targ.append(temp)
  return(s,targ)

# %%
env=env_opt_sd1(1,[3,5])
gamma = 0.9
epsilon = .95

trials = 100000
trial_len = len(env.jun_link)
succ_log=[]
# updateTargetNetwork = 1000
dqn_agent = DQN(env=env)
steps = []
succ=0
for trial in range(trials):
    temp_s,temp_d=randsd(env)
    env.reset(temp_s,temp_d)
    cur_state = env.state.reshape(1, len(env.state))
    #print('YOLO')
    for step in range(trial_len):
        action = dqn_agent.act(cur_state)
        new_state, reward, done= env.step(action)

        # reward = reward if not done else -20
        new_state = new_state.reshape(1, len(env.state))
        dqn_agent.remember(cur_state, action, reward, new_state, done)

        dqn_agent.replay()  # internally iterates default (prediction) model
        dqn_agent.target_train()  # iterates target model

        cur_state = new_state
        if done>0:
            break
    if done==1:
        print("Failed to complete in trial {}".format(trial))
of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10546
# 0.01896273821939888% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10547
# 0.018960940462646948% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10548
# 0.018959143046734288% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10549
# 0.018957345971563982% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10550
# 0.018955549237039144% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10551
# 0.018953752843062926% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10552
# 0.01895195678953852% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10553
# 0.01895016107636915% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10554
# 0.018948365703458078% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10555
# 0.018946570670708603% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10556
# 0.01894477597802406% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10557
# 0.018942981625307824% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10558
# 0.0189411876124633% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10559
# 0.01893939393939394% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10560
# 0.01893760060600322% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10561
# 0.01893580761219466% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10562
# 0.018934014957871816% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10563
# 0.01893222264293828% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10564
# 0.01893043066729768% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10565
# 0.01892863903085368% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10566
# 0.018926847733509986% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10567
# 0.018925056775170326% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10568
# 0.01892326615573848% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10569
# 0.01892147587511826% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10570
# 0.01891968593321351% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10571
# 0.018917896329928113% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10572
# 0.01891610706516599% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10573
# 0.018914318138831095% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10574
# 0.018912529550827423% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10575
# 0.018910741301059002% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10576
# 0.018908953389429894% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10577
# 0.018907165815844205% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10578
# 0.018905378580206068% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10579
# 0.01890359168241966% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10580
# 0.01890180512238919% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10581
# 0.0189000189000189% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10582
# 0.018898233015213078% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10583
# 0.01889644746787604% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10584
# 0.01889466225791214% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10585
# 0.01889287738522577% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10586
# 0.018891092849721357% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10587
# 0.018889308651303362% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10588
# 0.018887524789876285% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10589
# 0.018885741265344664% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10590
# 0.018883958077613068% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10591
# 0.0188821752265861% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10592
# 0.018880392712168414% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10593
# 0.018878610534264678% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10594
# 0.018876828692779613% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10595
# 0.01887504718761797% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10596
# 0.018873266018684533% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10597
# 0.018871485185884128% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10598
# 0.018869704689121615% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10599
# 0.018867924528301886% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10600
# 0.018866144703329875% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10601
# 0.018864365214110546% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10602
# 0.0188625860605489% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10603
# 0.01886080724254998% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10604
# 0.01885902876001886% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10605
# 0.018857250612860643% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10606
# 0.018855472800980485% of success
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10607
# 0.01885369532428356% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10608
# 0.018851918182675086% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10609
# 0.01885014137606032% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10610
# 0.018848364904344547% of success
# moved to valid position
# moved to valid position
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10611
# 0.018846588767433094% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10612
# 0.01884481296523132% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10613
# 0.01884303749764462% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10614
# 0.018841262364578427% of success
# moved to valid position
# Repeated destination
# Failed to complete in trial 10615
# 0.018839487565938208% of success
# moved to valid position
# moved to valid position
# Repeated destination
# Failed to complete in trial 10616
# 0.01883771310162946% of success
# moved to valid position
# moved to valid position
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3da420368339> in <module>()
#      23         dqn_agent.remember(cur_state, action, reward, new_state, done)
#      24
# ---> 25         dqn_agent.replay()  # internally iterates default (prediction) model
#      26         dqn_agent.target_train()  # iterates target model
#      27
#
# <ipython-input-4-255a6880629e> in replay(self)
#      57                 Q_future = max(self.target_model.predict(new_state)[0])
#      58                 target[0][action] = reward + Q_future * self.gamma
# ---> 59             self.model.fit(state, target, epochs=1, verbose=0)
#      60
#      61     def target_train(self):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=range(trial)
ll=2900
ul=3200
#plt.plot(x[ll:ul],succ_log[ll:ul])
plt.plot(x,succ_log)
plt.show()

# %%
plt.plot(x,succ_log)
plt.savefig('/content/drive/My Drive/Colab Notebooks/sales_vehicle/optimization/j2js_opt/game1/succ_plot.png')
